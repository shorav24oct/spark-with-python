# %%
employee_df = spark.read.format("csv")\
                .option("header","true")\
                .option("inferSchema","false")\
                .option("mode","PERMISSIVE")\
                .load("/Volumes/workspace/default/sks/employee_file.csv")

employee_df.show()

# %%
employee_df.columns

# %%
employee_df.printSchema()

# %%
employee_df.select("name").show()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %%
employee_df.select(col("id") + 5).show()

# %%
employee_df.select("id", col("name"), employee_df["age"], employee_df.salary).show()

# %%
employee_df = spark.read.format("csv")\
                .option("header","true")\
                .option("inferSchema","false")\
                .option("mode","DROPMALFORMED")\
                .load("/Volumes/workspace/default/sks/employee_file.csv")

employee_df.show()

# %%
employee_df = spark.read.format("csv")\
                .option("header","true")\
                .option("inferSchema","false")\
                .option("mode","FAILFAST")\
                .load("/Volumes/workspace/default/sks/employee_file.csv")

employee_df.show()

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

# %%
employee_schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("name", StringType(), True),
    StructField("age", IntegerType(), True),
    StructField("salary", IntegerType(), True),
    StructField("address", StringType(), True),
    StructField("nominee", StringType(), True),
    StructField("_corrupt_record", StringType(), True)
])

# %%
employee_df = spark.read.format("csv")\
                .option("header","true")\
                .option("inferSchema","true")\
                .schema(employee_schema)\
                .option("badRecordsPath","/Volumes/workspace/default/sks/")\
                .load("/Volumes/workspace/default/sks/employee_file.csv")

employee_df.show(truncate=False)

# %%
# %fs
ls /Volumes/workspace/default/sks/20260213T063228/bad_records

# %%
bad_data_df = spark.read.format("json").load("/Volumes/workspace/default/sks/20260213T063228/bad_records")
bad_data_df.show()
