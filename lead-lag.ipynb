# %%
product_data = [
(1,"iphone","01-01-2023",15000),
(2,"samsung","01-01-2023",11000),
(3,"oneplus","01-01-2023",23000),
(1,"iphone","01-02-2023",1300000),
(2,"samsung","01-02-2023",1120000),
(3,"oneplus","01-02-2023",1120000),
(1,"iphone","01-03-2023",1600000),
(2,"samsung","01-03-2023",1080000),
(3,"oneplus","01-03-2023",1160000),
(1,"iphone","01-04-2023",1700000),
(2,"samsung","01-04-2023",1800000),
(3,"oneplus","01-04-2023",1170000),
(1,"iphone","01-05-2023",1200000),
(2,"samsung","01-05-2023",980000),
(3,"oneplus","01-05-2023",1175000),
(1,"iphone","01-06-2023",1100000),
(2,"samsung","01-06-2023",1100000),
(3,"oneplus","01-06-2023",1200000)
]
product_schema = ["product_id","product_name","sales_date","sales"]
product_df = spark.createDataFrame(product_data,product_schema)

# %%
product_df.show()

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *
from pyspark.sql.window import Window

# %%
window = Window.partitionBy("product_id").orderBy("sales_date")

last_month_df = product_df.withColumn("previous_month_sale", lag("sales",1).over(window))

last_month_df.show()

# %%
last_month_df.withColumn("per_loss_gain", 
                         round(((col("sales") - col("previous_month_sale"))/col("sales"))*100,2))\
.show()

# %%
window = Window.partitionBy("product_id").orderBy("sales_date")\
.rangeBetween(Window.unboundedPreceding, Window.unboundedFollowing)

# %%
product_df.withColumn("first_sale", first("sales").over(window))\
            .withColumn("latest_sale", last("sales").over(window))\
            .withColumn("sale_diff", col("latest_sale") - col("first_sale"))\
            .withColumn("sale_diff_percent", round((col("sale_diff")/col("first_sale"))*100,2))\
            .show()

# %%
product_df.withColumn("first_sale", first("sales").over(window))\
            .withColumn("latest_sale", last("sales").over(window))\
            .withColumn("sale_diff", col("latest_sale") - col("first_sale"))\
            .show()
